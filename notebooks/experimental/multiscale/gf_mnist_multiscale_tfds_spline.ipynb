# %% [markdown]
# # GFs for MNIST (Multiscale)

# %%
# @title Install Packages
# %%capture
try:
    import sys, os
    from pyprojroot import here

    # spyder up to find the root
    root = here(project_files=[".here"])

    # append to path
    sys.path.append(str(root))
except ModuleNotFoundError:
    import os

    os.system("pip install objax chex")
    os.system("pip install git+https://github.com/IPL-UV/rbig_jax.git#egg=rbig_jax")

# %%
# jax packages
import jax
import jax.numpy as jnp
from jax.config import config

# import chex
config.update("jax_enable_x64", False)

import chex
import numpy as np
from functools import partial

# Plot utilities
from rbig_jax.custom_types import ImageShape
from rbig_jax.plots import plot_image_grid


KEY = jax.random.PRNGKey(123)

# logging
import tqdm
import wandb

# plot methods
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
import corner
from IPython.display import HTML

sns.reset_defaults()
sns.set_context(context="talk", font_scale=0.7)

# %load_ext lab_black
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %% [markdown]
# ## Demo Data
#
# In this demonstration, we will be using the "mnist" dataset.

# %%
import tensorflow as tf

(X_train, _), (X_test) = tf.keras.datasets.mnist.load_data()
image_shape = ImageShape(28, 28, 1)

n_init = 10_000

X_init = X_train[:n_init]

# %%
# plot batch of images

fig, ax = plot_image_grid(X_init)
plt.show()

# %% [markdown]
# ### Preprocessing Steps
#
# 1. Dequantize the variables
#
# Basically add some uniform noise to help with training.
#
# 2. Normalize the pixels
#
# We constrain the pixels to be from $[0, 256)$ to $[0, 1)$.

# %%
from typing import Optional, Mapping
from chex import Array
from einops import rearrange

PRNGKey = Array
Batch = Mapping[str, np.ndarray]


def prepare_data(batch: Batch, prng_key: Optional[PRNGKey] = None) -> Array:

    # select image from tfds
    data = batch.astype(jnp.float32)

    # (N,H,W)-> (N,C,H,W)
    data = jnp.expand_dims(data, axis=3)

    # dequantize pixels (training only)
    if prng_key is not None:
        # Dequantize pixel values {0, 1, ..., 255} with uniform noise [0, 1).
        data += jax.random.uniform(prng_key, data.shape).astype(jnp.float32)

    # flatten image data
    data = rearrange(data, "B H W C -> B (H W C)")

    return data / 256.0  # Normalize pixel values from [0, 256) to [0, 1).

# %% [markdown]
# #### Demo

# %%
# create key
rng, prng_key = jax.random.split(KEY, num=2)

# prep the data
X_init_prepped = prepare_data(X_init, prng_key=prng_key)

# plot image grid
fig, ax = plot_image_grid(X_init_prepped, image_shape)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Initialize Data

# %%
model = "mixture"

# %%
n_reflections = 10
init_rotation = "random"

# nn params
n_blocks = 6
image_shape = ImageShape(C=1, H=28, W=28)
filters = [(2, 2), (4, 4), (7, 7,), (14, 14)]

# %%
if model == "splines":
    from rbig_jax.models.gaussflow import init_gf_spline_model

    # marginal uniformization
    n_bins = 8
    range_min = -12
    range_max = 12
    boundary_slopes = "unconstrained"
    identity_init = False

    plot_layers = False
    plot_blocks = False

elif model == "mixture":
    from rbig_jax.models.gaussflow import init_default_gf_model

    mixture = "gaussian"
    inverse_cdf = "gaussian"
    init_mixcdf = "gmm"
    n_components = 10
else:
    raise ValueError(f"Unrecognized Model: {model}")

# %%
if model == "splines":
    from rbig_jax.models.multiscale import init_multiscale_flow_spline

    # init model
    X_g, gf_model = init_multiscale_flow_spline(
        seed=42,
        image_shape=image_shape,
        filters=filters,
        X=X_init_prepped,
        n_blocks=n_blocks,
        n_bins=n_bins,
        range_min=range_min,
        range_max=range_max,
        boundary_slopes=boundary_slopes,
        identity_init=identity_init,
        n_reflections=n_reflections,
        init_rotation=init_rotation,
        return_transform=True,
    )

elif model == "mixture":
    from rbig_jax.models.multiscale import init_multiscale_flow

    # init model
    X_g, gf_model = init_multiscale_flow(
        seed=42,
        image_shape=image_shape,
        filters=filters,
        X=X_init_prepped,
        n_blocks=n_blocks,
        n_components=n_components,
        inverse_cdf=inverse_cdf,
        init_mixcdf=init_mixcdf,
        mixture=mixture,
        n_reflections=n_reflections,
        init_rotation=init_rotation,
        return_transform=True,
    )
else:
    raise ValueError(f"Unrecognized Model: {model}")
# Out:
# Filter: (2, 2) - Layer: 0 - X: (10000, 784)- Initializing MixCDF:   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 1:   0%|          | 0/6 [01:23<?, ?it/s]
# Initializing - Block: 1 | Layer 2:   0%|          | 0/6 [01:24<?, ?it/s]
# Initializing - Block: 1 | Layer 2:  17%|█▋        | 1/6 [01:24<07:02, 84.60s/it]
# Initializing - Block: 2 | Layer 3:  17%|█▋        | 1/6 [01:24<07:02, 84.60s/it]
# Initializing - Block: 2 | Layer 4:  17%|█▋        | 1/6 [02:58<07:02, 84.60s/it]
# Initializing - Block: 2 | Layer 5:  17%|█▋        | 1/6 [02:59<07:02, 84.60s/it]
# Initializing - Block: 2 | Layer 5:  33%|███▎      | 2/6 [02:59<06:02, 90.72s/it]
# Initializing - Block: 3 | Layer 6:  33%|███▎      | 2/6 [02:59<06:02, 90.72s/it]
# Initializing - Block: 3 | Layer 7:  33%|███▎      | 2/6 [04:38<06:02, 90.72s/it]
# Initializing - Block: 3 | Layer 8:  33%|███▎      | 2/6 [04:39<06:02, 90.72s/it]
# Initializing - Block: 3 | Layer 8:  50%|█████     | 3/6 [04:39<04:45, 95.08s/it]
# Initializing - Block: 4 | Layer 9:  50%|█████     | 3/6 [04:39<04:45, 95.08s/it]
# Initializing - Block: 4 | Layer 10:  50%|█████     | 3/6 [06:19<04:45, 95.08s/it]
# Initializing - Block: 4 | Layer 11:  50%|█████     | 3/6 [06:20<04:45, 95.08s/it]
# Initializing - Block: 4 | Layer 11:  67%|██████▋   | 4/6 [06:21<03:14, 97.48s/it]
# Initializing - Block: 5 | Layer 12:  67%|██████▋   | 4/6 [06:21<03:14, 97.48s/it]
# Initializing - Block: 5 | Layer 13:  67%|██████▋   | 4/6 [08:03<03:14, 97.48s/it]
# Initializing - Block: 5 | Layer 14:  67%|██████▋   | 4/6 [08:04<03:14, 97.48s/it]
# Initializing - Block: 5 | Layer 14:  83%|████████▎ | 5/6 [08:04<01:39, 99.72s/it]
# Initializing - Block: 6 | Layer 15:  83%|████████▎ | 5/6 [08:04<01:39, 99.72s/it]
# Initializing - Block: 6 | Layer 16:  83%|████████▎ | 5/6 [09:51<01:39, 99.72s/it]
# Initializing - Block: 6 | Layer 17:  83%|████████▎ | 5/6 [09:52<01:39, 99.72s/it]
# Initializing - Block: 6 | Layer 17: 100%|██████████| 6/6 [09:53<00:00, 98.84s/it]
# Filter: (4, 4) - Layer: 1 - X: (10000, 784)- Initializing MixCDF:  25%|██▌       | 1/4 [09:53<29:39, 593.09s/it]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 1:   0%|          | 0/6 [01:58<?, ?it/s]
# Initializing - Block: 1 | Layer 2:   0%|          | 0/6 [01:59<?, ?it/s]
# Initializing - Block: 1 | Layer 2:  17%|█▋        | 1/6 [01:59<09:58, 119.61s/it]
# Initializing - Block: 2 | Layer 3:  17%|█▋        | 1/6 [01:59<09:58, 119.61s/it]
# Initializing - Block: 2 | Layer 4:  17%|█▋        | 1/6 [03:45<09:58, 119.61s/it]
# Initializing - Block: 2 | Layer 5:  17%|█▋        | 1/6 [03:46<09:58, 119.61s/it]
# Initializing - Block: 2 | Layer 5:  33%|███▎      | 2/6 [03:46<07:29, 112.27s/it]
# Initializing - Block: 3 | Layer 6:  33%|███▎      | 2/6 [03:46<07:29, 112.27s/it]
# Initializing - Block: 3 | Layer 7:  33%|███▎      | 2/6 [05:35<07:29, 112.27s/it]
# Initializing - Block: 3 | Layer 8:  33%|███▎      | 2/6 [05:36<07:29, 112.27s/it]
# Initializing - Block: 3 | Layer 8:  50%|█████     | 3/6 [05:36<05:34, 111.35s/it]
# Initializing - Block: 4 | Layer 9:  50%|█████     | 3/6 [05:36<05:34, 111.35s/it]
# Initializing - Block: 4 | Layer 10:  50%|█████     | 3/6 [07:24<05:34, 111.35s/it]
# Initializing - Block: 4 | Layer 11:  50%|█████     | 3/6 [07:25<05:34, 111.35s/it]
# Initializing - Block: 4 | Layer 11:  67%|██████▋   | 4/6 [07:26<03:40, 110.49s/it]
# Initializing - Block: 5 | Layer 12:  67%|██████▋   | 4/6 [07:26<03:40, 110.49s/it]
# Initializing - Block: 5 | Layer 13:  67%|██████▋   | 4/6 [09:16<03:40, 110.49s/it]
# Initializing - Block: 5 | Layer 14:  67%|██████▋   | 4/6 [09:17<03:40, 110.49s/it]
# Initializing - Block: 5 | Layer 14:  83%|████████▎ | 5/6 [09:17<01:50, 110.92s/it]
# Initializing - Block: 6 | Layer 15:  83%|████████▎ | 5/6 [09:17<01:50, 110.92s/it]
# Initializing - Block: 6 | Layer 16:  83%|████████▎ | 5/6 [11:06<01:50, 110.92s/it]
# Initializing - Block: 6 | Layer 17:  83%|████████▎ | 5/6 [11:07<01:50, 110.92s/it]
# Initializing - Block: 6 | Layer 17: 100%|██████████| 6/6 [11:07<00:00, 111.27s/it]
# Filter: (7, 7) - Layer: 2 - X: (10000, 784)- Initializing MixCDF:  50%|█████     | 2/4 [21:00<21:14, 637.03s/it]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 1:   0%|          | 0/6 [02:24<?, ?it/s]
# Initializing - Block: 1 | Layer 2:   0%|          | 0/6 [02:24<?, ?it/s]
# Initializing - Block: 1 | Layer 2:  17%|█▋        | 1/6 [02:25<12:06, 145.21s/it]
# Initializing - Block: 2 | Layer 3:  17%|█▋        | 1/6 [02:25<12:06, 145.21s/it]
# Initializing - Block: 2 | Layer 4:  17%|█▋        | 1/6 [04:44<12:06, 145.21s/it]
# Initializing - Block: 2 | Layer 5:  17%|█▋        | 1/6 [04:45<12:06, 145.21s/it]
# Initializing - Block: 2 | Layer 5:  33%|███▎      | 2/6 [04:45<09:30, 142.57s/it]
# Initializing - Block: 3 | Layer 6:  33%|███▎      | 2/6 [04:45<09:30, 142.57s/it]
# Initializing - Block: 3 | Layer 7:  33%|███▎      | 2/6 [07:04<09:30, 142.57s/it]
# Initializing - Block: 3 | Layer 8:  33%|███▎      | 2/6 [07:05<09:30, 142.57s/it]
# Initializing - Block: 3 | Layer 8:  50%|█████     | 3/6 [07:05<07:03, 141.31s/it]
# Initializing - Block: 4 | Layer 9:  50%|█████     | 3/6 [07:05<07:03, 141.31s/it]
# Initializing - Block: 4 | Layer 10:  50%|█████     | 3/6 [09:30<07:03, 141.31s/it]
# Initializing - Block: 4 | Layer 11:  50%|█████     | 3/6 [09:31<07:03, 141.31s/it]
# Initializing - Block: 4 | Layer 11:  67%|██████▋   | 4/6 [09:32<04:46, 143.32s/it]
# Initializing - Block: 5 | Layer 12:  67%|██████▋   | 4/6 [09:32<04:46, 143.32s/it]
# Initializing - Block: 5 | Layer 13:  67%|██████▋   | 4/6 [11:53<04:46, 143.32s/it]
# Initializing - Block: 5 | Layer 14:  67%|██████▋   | 4/6 [11:54<04:46, 143.32s/it]
# Initializing - Block: 5 | Layer 14:  83%|████████▎ | 5/6 [11:55<02:23, 143.24s/it]
# Initializing - Block: 6 | Layer 15:  83%|████████▎ | 5/6 [11:55<02:23, 143.24s/it]
# Initializing - Block: 6 | Layer 16:  83%|████████▎ | 5/6 [14:15<02:23, 143.24s/it]
# Initializing - Block: 6 | Layer 17:  83%|████████▎ | 5/6 [14:16<02:23, 143.24s/it]
# Initializing - Block: 6 | Layer 17: 100%|██████████| 6/6 [14:17<00:00, 142.87s/it]
# Filter: (14, 14) - Layer: 3 - X: (10000, 784)- Initializing MixCDF:  75%|███████▌  | 3/4 [35:18<12:17, 737.61s/it]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 1:   0%|          | 0/6 [04:04<?, ?it/s]
# Initializing - Block: 1 | Layer 2:   0%|          | 0/6 [04:05<?, ?it/s]
# Initializing - Block: 1 | Layer 2:  17%|█▋        | 1/6 [04:05<20:28, 245.65s/it]
# Initializing - Block: 2 | Layer 3:  17%|█▋        | 1/6 [04:05<20:28, 245.65s/it]
# Initializing - Block: 2 | Layer 4:  17%|█▋        | 1/6 [07:56<20:28, 245.65s/it]
# Initializing - Block: 2 | Layer 5:  17%|█▋        | 1/6 [07:57<20:28, 245.65s/it]
# Initializing - Block: 2 | Layer 5:  33%|███▎      | 2/6 [07:58<15:51, 237.95s/it]
# Initializing - Block: 3 | Layer 6:  33%|███▎      | 2/6 [07:58<15:51, 237.95s/it]
# Initializing - Block: 3 | Layer 7:  33%|███▎      | 2/6 [12:02<15:51, 237.95s/it]
# Initializing - Block: 3 | Layer 8:  33%|███▎      | 2/6 [12:04<15:51, 237.95s/it]
# Initializing - Block: 3 | Layer 8:  50%|█████     | 3/6 [12:04<12:05, 241.78s/it]
# Initializing - Block: 4 | Layer 9:  50%|█████     | 3/6 [12:04<12:05, 241.78s/it]
# Initializing - Block: 4 | Layer 10:  50%|█████     | 3/6 [15:49<12:05, 241.78s/it]
# Initializing - Block: 4 | Layer 11:  50%|█████     | 3/6 [15:50<12:05, 241.78s/it]
# Initializing - Block: 4 | Layer 11:  67%|██████▋   | 4/6 [15:50<07:51, 235.64s/it]
# Initializing - Block: 5 | Layer 12:  67%|██████▋   | 4/6 [15:50<07:51, 235.64s/it]
# Initializing - Block: 5 | Layer 13:  67%|██████▋   | 4/6 [19:41<07:51, 235.64s/it]
# Initializing - Block: 5 | Layer 14:  67%|██████▋   | 4/6 [19:42<07:51, 235.64s/it]
# Initializing - Block: 5 | Layer 14:  83%|████████▎ | 5/6 [19:43<03:54, 234.44s/it]
# Initializing - Block: 6 | Layer 15:  83%|████████▎ | 5/6 [19:43<03:54, 234.44s/it]
# Initializing - Block: 6 | Layer 16:  83%|████████▎ | 5/6 [23:57<03:54, 234.44s/it]
# Initializing - Block: 6 | Layer 17:  83%|████████▎ | 5/6 [23:58<03:54, 234.44s/it]
# Initializing - Block: 6 | Layer 17: 100%|██████████| 6/6 [23:59<00:00, 239.84s/it]
# Filter: (14, 14) - Layer: 3 - X: (10000, 784)- Initializing MixCDF: 100%|██████████| 4/4 [59:17<00:00, 889.33s/it]

# %% [markdown]
# ### Demo Transformation

# %% [markdown]
# #### Forward

# %%
# plot demo images
# plot image grid
fig, ax = plot_image_grid(X_g, image_shape)

# %%
fig = corner.corner(np.array(X_g[:, :10]), color="red")

# %% [markdown]
# ### Initial Score

# %% [markdown]
# #### Negative Log-Likelihood

# %%
# %%time


init_nll_score = gf_model.score(X_init_prepped[:64])

print(f"NLL", init_nll_score)
# Out:
# NLL -3231.9712
# CPU times: user 16.1 s, sys: 308 ms, total: 16.4 s
# Wall time: 13 s

# %% [markdown]
# #### NLL - Bits per Dimension

# %%
from rbig_jax.losses import nll_2_bpd

# jit the loss
nll_2_bpd = jax.jit(nll_2_bpd)

init_nll_score_bpd = nll_2_bpd(init_nll_score, image_shape)

print(f"NLL (bits-per-dim)", init_nll_score_bpd)
# Out:
# NLL (bits-per-dim) -5.947384

# %% [markdown]
# #### Inverse

# %%
# %%time

# forward propagation for data
X_demo_approx = gf_model.inverse(X_g[:25])
# Out:
# CPU times: user 7min 57s, sys: 39.6 s, total: 8min 37s
# Wall time: 1min 41s

# %%
# plot demo images
plot_image_grid(X_demo_approx, image_shape)
# Out:
# (<Figure size 720x720 with 50 Axes>,
#  <mpl_toolkits.axes_grid1.axes_grid.ImageGrid at 0x7fb5080285e0>)

# %% [markdown]
# ### Loss Function
#
# We're going to minimize the log probability

# %%
from rbig_jax.training.parametric import init_optimizer

n_epochs = 5_000
# initialize optimizer
optimizer = init_optimizer(
    "adam", lr=1e-3, cosine_decay_steps=n_epochs, gradient_norm_clip=1.0, alpha=1e-1,
)

# %% [markdown]
# ### NF Trainer

# %%
from rbig_jax.training.parametric import GaussFlowTrainer

# initial flow trainer
nf_trainer = GaussFlowTrainer(
    gf_model, optimizer, n_epochs=n_epochs, prepare_data_fn=prepare_data
)

# %% [markdown]
# ### DataLoaders

# %%
import tensorflow_datasets as tfds
from typing import Iterator, Mapping
from sklearn import datasets
import numpy as np
import tensorflow as tf

Batch = Mapping[str, np.ndarray]

# %%
def load_dataset(split: str = "train", batch_size: int = 123) -> Iterator[Batch]:
    (X_train, _), (X_test) = tf.keras.datasets.mnist.load_data()
    if split == "train":
        ds = tf.data.Dataset.from_tensor_slices((X_train))
    elif split == "test":
        ds = tf.data.Dataset.from_tensor_slices((X_test))
    else:
        raise ValueError(f"Unrecognized split")

    ds = ds.shuffle(buffer_size=10 * batch_size)
    ds = ds.batch(batch_size)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    ds = ds.repeat()
    return iter(tfds.as_numpy(ds))

# %%
train_batch_size = 64
valid_batch_size = 1_000

train_ds = load_dataset("train", train_batch_size)
valid_ds = load_dataset("test", valid_batch_size)

# %%
# number of epochs
# epochs = 250
eval_frequency = 50
# split the keys into a unique subset
train_rng = jax.random.split(rng, num=n_epochs)

# create an iterator
train_rng = iter(train_rng)

# %% [markdown]
# ### Train Loop

# %%
# %%wandb

import tqdm

eval_loss = 0.0
eval_frequency = 50
with tqdm.trange(n_epochs) as pbar:
    for step in pbar:

        # Train Step
        output = nf_trainer.train_step(next(train_ds), rng=next(train_rng))
        train_loss = output.loss
        train_loss = nll_2_bpd(train_loss, image_shape)
        pbar.set_description(
            f"Train Loss: {train_loss:.4f} | Valid Loss: {eval_loss:.4f}"
        )

        # Eval Step
        if step % eval_frequency == 0:
            output = nf_trainer.validation_step(next(valid_ds))
            eval_loss = output.loss
            eval_loss = nll_2_bpd(eval_loss, X_init.shape[1:])
            pbar.set_description(
                f"Train Loss: {train_loss:.4f} | Valid Loss: {eval_loss:.4f}"
            )

gf_model = output.model
# Out:
# Train Loss: 49.1164 | Valid Loss: 0.0000:   0%|          | 0/5000 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# FilteredStackTrace                        Traceback (most recent call last)
# <ipython-input-58-ec1c0e2c6ead> in <module>
#      19         if step % eval_frequency == 0:
# ---> 20             output = nf_trainer.validation_step(next(valid_ds))
#      21             eval_loss = output.loss
#
# ~/code/rbig_jax/rbig_jax/training/parametric.py in validation_step(self, data)
#      94         # do a gradient step
# ---> 95         valid_loss = self.eval_fn(model, data)
#      96
#
# ~/code/rbig_jax/rbig_jax/training/parametric.py in eval_fn(self, model, batch)
#     149         if self.prepare_data_fn is not None:
# --> 150             batch = self.prepare_data_fn(batch)
#     151         # negative log likelihood loss
#
# <ipython-input-39-7039e972e0c9> in prepare_data(batch, prng_key)
#      11     # select image from tfds
# ---> 12     data = batch.astype(jnp.float32)
#      13
#
# FilteredStackTrace: AttributeError: 'tuple' object has no attribute 'astype'
#
# The stack trace above excludes JAX-internal frames.
# The following is the original exception that occurred, unmodified.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-ec1c0e2c6ead> in <module>
#      18         # Eval Step
#      19         if step % eval_frequency == 0:
# ---> 20             output = nf_trainer.validation_step(next(valid_ds))
#      21             eval_loss = output.loss
#      22             eval_loss = nll_2_bpd(eval_loss, X_init.shape[1:])
#
# ~/code/rbig_jax/rbig_jax/training/parametric.py in validation_step(self, data)
#      93
#      94         # do a gradient step
# ---> 95         valid_loss = self.eval_fn(model, data)
#      96
#      97         self.valid_loss.append(valid_loss)
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     405           return cache_miss(*args, **kwargs)[0]  # probably won't return
#     406       else:
# --> 407         return cpp_jitted_f(*args, **kwargs)
#     408
#     409   f_jitted._cpp_jitted_f = cpp_jitted_f
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/jax/api.py in cache_miss(*args, **kwargs)
#     293       _check_arg(arg)
#     294     flat_fun, out_tree = flatten_fun(f, in_tree)
# --> 295     out_flat = xla.xla_call(
#     296         flat_fun,
#     297         *args_flat,
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1400
#    1401   def bind(self, fun, *args, **params):
# -> 1402     return call_bind(self, fun, *args, **params)
#    1403
#    1404   def process(self, trace, fun, tracers, params):
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1391   tracers = map(top_trace.full_raise, args)
#    1392   with maybe_new_sublevel(top_trace):
# -> 1393     outs = primitive.process(top_trace, fun, tracers, params)
#    1394   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1395
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1403
#    1404   def process(self, trace, fun, tracers, params):
# -> 1405     return trace.process_call(self, fun, tracers, params)
#    1406
#    1407   def post_process(self, trace, out_tracers, params):
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/jax/core.py in process_call(self, primitive, f, tracers, params)
#     598
#     599   def process_call(self, primitive, f, tracers, params):
# --> 600     return primitive.impl(f, *tracers, **params)
#     601   process_map = process_call
#     602
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/jax/interpreters/xla.py in _xla_call_impl(fun, device, backend, name, donated_invars, *args)
#     575
#     576 def _xla_call_impl(fun: lu.WrappedFun, *args, device, backend, name, donated_invars):
# --> 577   compiled_fun = _xla_callable(fun, device, backend, name, donated_invars,
#     578                                *unsafe_map(arg_spec, args))
#     579   try:
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/jax/linear_util.py in memoized_fun(fun, *args)
#     258       fun.populate_stores(stores)
#     259     else:
# --> 260       ans = call(fun, *args)
#     261       cache[key] = (ans, fun.stores)
#     262
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/jax/interpreters/xla.py in _xla_callable(fun, device, backend, name, donated_invars, *arg_specs)
#     652   abstract_args, arg_devices = unzip2(arg_specs)
#     653   if config.omnistaging_enabled:
# --> 654     jaxpr, out_avals, consts = pe.trace_to_jaxpr_final(fun, abstract_args)
#     655     if any(isinstance(c, core.Tracer) for c in consts):
#     656       raise core.UnexpectedTracerError("Encountered an unexpected tracer.")
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr_final(fun, in_avals)
#    1226     main.source_info = fun_sourceinfo(fun.f)  # type: ignore
#    1227     main.jaxpr_stack = ()  # type: ignore
# -> 1228     jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1229     del fun, main
#    1230   return jaxpr, out_avals, consts
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1206     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1207     in_tracers = map(trace.new_arg, in_avals)
# -> 1208     ans = fun.call_wrapped(*in_tracers)
#    1209     out_tracers = map(trace.full_raise, ans)
#    1210     jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     164
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#     168       # Some transformations yield from inside context managers, so we have to
#
# ~/code/rbig_jax/rbig_jax/training/parametric.py in eval_fn(self, model, batch)
#     148     def eval_fn(self, model, batch):
#     149         if self.prepare_data_fn is not None:
# --> 150             batch = self.prepare_data_fn(batch)
#     151         # negative log likelihood loss
#     152         nll_loss = model.score(batch)
#
# <ipython-input-39-7039e972e0c9> in prepare_data(batch, prng_key)
#      10
#      11     # select image from tfds
# ---> 12     data = batch.astype(jnp.float32)
#      13
#      14     # (N,H,W)-> (N,C,H,W)
#
# AttributeError: 'tuple' object has no attribute 'astype'

# %% [markdown]
# ## Results

# %%
fig, ax = plt.subplots()
ax.plot(
    nf_trainer.train_epoch, nf_trainer.train_loss, label="Training Loss", color="blue"
)
ax.plot(
    nf_trainer.valid_epoch,
    nf_trainer.valid_loss,
    label="Validation Loss",
    color="orange",
)
ax.set(
    xlabel="Iterations", ylabel="Negative Log-Likelihood",
)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# %%time

# forward propagation for data
X_demo_g = gf_model.forward(X_init)

# plot demo images
# plot image grid
fig, ax = plot_image_grid(X_demo_g, image_shape)
# Out:
# CPU times: user 26.4 s, sys: 3.34 s, total: 29.7 s
# Wall time: 9.98 s

# %%
fig = corner.corner(np.array(X_demo_g[:, :5]), color="red")
wandb.log({"final_latent_histogram": wandb.Image(plt)})

# %%
# %%time

# forward propagation for data
X_demo_approx = gf_model.inverse(X_demo_g)

# plot demo images
# plot image grid
fig, ax = plot_image_grid(X_demo_approx, image_shape)
# plot image grid
# Out:
# CPU times: user 27.2 s, sys: 3.04 s, total: 30.3 s
# Wall time: 9.82 s

# %% [markdown]
# ### Sampling

# %%
# %%time

# X_g_samples = jax.random.randn((5_000, 784))
n_gen_samples = 10_000
X_samples = gf_model.sample(seed=123, n_samples=n_gen_samples)

# plot
fig, ax = plot_image_grid(X_samples, image_shape)
# Out:
# CPU times: user 53.5 s, sys: 7.44 s, total: 1min
# Wall time: 18.6 s

# %%
fig = corner.corner(np.array(X_samples[:, :5]), color="Blue")

# %%
X_g = X_init.copy()[:50]

fig = corner.corner(X_g, color="purple")
fig.suptitle("Initial")
plt.show()

for ilayer, ibijector in enumerate(gf_model.bijectors):
    
    X_g = ibijector.forward(X_g)
    
    if (ilayer+1) % 3 == 0:
        fig = corner.corner(X_g[:,:5], color="purple")
        fig.suptitle(f"Block: {(ilayer+1)//3}")
        plt.show()
        
        break
# Out:
# Error in callback <function _WandbInit._resume_backend at 0x7f0d6061f790> (for pre_run_cell):
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/backcall/backcall.py in adapted(*args, **kwargs)
#     102                 kwargs.pop(name)
#     103 #            print(args, kwargs, unmatched_pos, cut_positional, unmatched_kw)
# --> 104             return callback(*args, **kwargs)
#     105
#     106         return adapted
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/wandb_init.py in _resume_backend(self)
#     257         if self.backend is not None:
#     258             logger.info("resuming backend")
# --> 259             self.backend.interface.publish_resume()
#     260
#     261     def _jupyter_teardown(self):
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/interface/interface.py in publish_resume(self)
#     595         resume = pb.ResumeRequest()
#     596         rec = self._make_request(resume=resume)
# --> 597         self._publish(rec)
#     598
#     599     def _publish_run(self, run: pb.RunRecord) -> None:
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/interface/interface.py in _publish(self, record, local)
#     526     def _publish(self, record: pb.Record, local: bool = None) -> None:
#     527         if self._process and not self._process.is_alive():
# --> 528             raise Exception("The wandb backend process has shutdown")
#     529         if local:
#     530             record.control.local = local
#
# Exception: The wandb backend process has shutdown
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-57-833f71363764> in <module>
#       1 X_g = X_init.copy()[:50]
#       2
# ----> 3 fig = corner.corner(X_g, color="purple")
#       4 fig.suptitle("Initial")
#       5 plt.show()
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/corner/corner.py in corner(xs, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, **hist2d_kwargs)
#     191         assert len(xs.shape) == 2, "The input sample array must be 1- or 2-D."
#     192         xs = xs.T
# --> 193     assert xs.shape[0] <= xs.shape[1], (
#     194         "I don't believe that you want more " "dimensions than samples!"
#     195     )
#
# AssertionError: I don't believe that you want more dimensions than samples!
# Error in callback <function _WandbInit._pause_backend at 0x7f0d6061f310> (for post_run_cell):
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/backcall/backcall.py in adapted(*args, **kwargs)
#     102                 kwargs.pop(name)
#     103 #            print(args, kwargs, unmatched_pos, cut_positional, unmatched_kw)
# --> 104             return callback(*args, **kwargs)
#     105
#     106         return adapted
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/wandb_init.py in _pause_backend(self)
#     252                 res = self.run.log_code(root=None)
#     253                 logger.info("saved code: %s", res)
# --> 254             self.backend.interface.publish_pause()
#     255
#     256     def _resume_backend(self):
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/interface/interface.py in publish_pause(self)
#     590         pause = pb.PauseRequest()
#     591         rec = self._make_request(pause=pause)
# --> 592         self._publish(rec)
#     593
#     594     def publish_resume(self) -> None:
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/interface/interface.py in _publish(self, record, local)
#     526     def _publish(self, record: pb.Record, local: bool = None) -> None:
#     527         if self._process and not self._process.is_alive():
# --> 528             raise Exception("The wandb backend process has shutdown")
#     529         if local:
#     530             record.control.local = local
#
# Exception: The wandb backend process has shutdown
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "/home/emmanuel/.conda/envs/jax_py38/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/emmanuel/.conda/envs/jax_py38/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/emmanuel/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/wandb_run.py", line 198, in check_status
#     status_response = self._interface.communicate_stop_status()
#   File "/home/emmanuel/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/interface/interface.py", line 735, in communicate_stop_status
#     resp = self._communicate(req, timeout=timeout, local=True)
#   File "/home/emmanuel/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/interface/interface.py", line 537, in _communicate
#     return self._communicate_async(rec, local=local).get(timeout=timeout)
#   File "/home/emmanuel/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/interface/interface.py", line 542, in _communicate_async
#     raise Exception("The wandb backend process has shutdown")
# Exception: The wandb backend process has shutdown

# %%
fig, ax = plt.subplots()
ax.scatter(X_g[:, 0], X_g[:, 1], s=3)
ax.set_aspect('equal', 'box')
plt.tight_layout()

# %% [markdown]
# ## Saving/Loading Model

# %%
import joblib

# %% [markdown]
# #### Save Model

# %%
model_save_name = os.path.join(wandb.run.dir, "gf_model.pckl")
joblib.dump(gf_model, model_save_name)
wandb.save(model_save_name)
# Out:
# ['gf_model_mnist.pickle']

# %% [markdown]
# #### Load Model

# %%
gf_model_ = joblib.load(model_save_name)
