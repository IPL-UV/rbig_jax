# %% [markdown]
# # GFs for MNIST (Multiscale - Rotation)

# %%
# @title Install Packages
# %%capture
try:
    import sys, os
    from pyprojroot import here

    # spyder up to find the root
    root = here(project_files=[".here"])

    # append to path
    sys.path.append(str(root))
except ModuleNotFoundError:
    import os

    # !pip install git+https://github.com/IPL-UV/rbig_jax.git

# %%
# jax packages
import jax
import jax.numpy as jnp
from jax.config import config

# import chex
config.update("jax_enable_x64", False)

import chex
import numpy as np
from functools import partial

# Plot utilities
from rbig_jax.custom_types import ImageShape
from rbig_jax.plots import plot_image_grid


KEY = jax.random.PRNGKey(123)

# logging
import tqdm

# plot methods
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
import corner
from IPython.display import HTML

sns.reset_defaults()
sns.set_context(context="talk", font_scale=0.7)

# %load_ext lab_black
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %% [markdown]
# ## Demo Data
#
# In this demonstration, we will be using the "mnist" dataset.

# %%
import tensorflow as tf

(X_train, _), (X_test) = tf.keras.datasets.mnist.load_data()
image_shape = ImageShape(28, 28, 1)

n_init = 5_000

X_init = X_train[:n_init]

# %%
# plot batch of images

fig, ax = plot_image_grid(X_init)
plt.show()

# %% [markdown]
# ### Preprocessing Steps
#
# 1. Dequantize the variables
#
# Basically add some uniform noise to help with training.
#
# 2. Normalize the pixels
#
# We constrain the pixels to be from $[0, 256)$ to $[0, 1)$.

# %%
from typing import Optional, Mapping
from chex import Array
from einops import rearrange

PRNGKey = Array
Batch = Mapping[str, np.ndarray]


def prepare_data(batch: Batch, prng_key: Optional[PRNGKey] = None) -> Array:

    # select image from tfds
    data = batch.astype(jnp.float32)

    # (N,H,W)-> (N,C,H,W)
    data = jnp.expand_dims(data, axis=3)

    # dequantize pixels (training only)
    if prng_key is not None:
        # Dequantize pixel values {0, 1, ..., 255} with uniform noise [0, 1).
        data += jax.random.uniform(prng_key, data.shape).astype(jnp.float32)

    # flatten image data
    data = rearrange(data, "B H W C -> B (H W C)")

    return data / 256.0  # Normalize pixel values from [0, 256) to [0, 1).

# %% [markdown]
# #### Demo

# %%
# create key
rng, prng_key = jax.random.split(KEY, num=2)

# prep the data
X_init_prepped = prepare_data(X_init, prng_key=prng_key)

# plot image grid
fig, ax = plot_image_grid(X_init_prepped, image_shape)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Initialize Data

# %%
model = "splines"

# %%
n_reflections = 10
init_rotation = "random"

# nn params
n_blocks = 10
image_shape = ImageShape(C=1, H=28, W=28)
filters = [(2, 2), (4, 4), (7, 7,), (14, 14), (28, 28)]

# %%
if model == "splines":
    from rbig_jax.models.gaussflow import init_gf_spline_model

    # marginal uniformization
    n_bins = 8
    range_min = -12
    range_max = 12
    boundary_slopes = "unconstrained"
    identity_init = True

    plot_layers = False
    plot_blocks = False

elif model == "mixture":
    from rbig_jax.models.gaussflow import init_default_gf_model

    mixture = "gaussian"
    inverse_cdf = "gaussian"
    init_mixcdf = "gmm"
    n_components = 10
else:
    raise ValueError(f"Unrecognized Model: {model}")

# %%
if model == "splines":
    from rbig_jax.models.multiscale import init_rot_multiscale_flow_spline

    # init model
    X_g, gf_model = init_rot_multiscale_flow_spline(
        seed=42,
        image_shape=image_shape,
        filters=filters,
        X=X_init_prepped,
        n_blocks=n_blocks,
        n_bins=n_bins,
        range_min=range_min,
        range_max=range_max,
        boundary_slopes=boundary_slopes,
        identity_init=identity_init,
        n_reflections=n_reflections,
        init_rotation=init_rotation,
        return_transform=True,
    )

elif model == "mixture":
    from rbig_jax.models.multiscale import init_multiscale_flow

    # init model
    X_g, gf_model = init_multiscale_flow(
        seed=42,
        image_shape=image_shape,
        filters=filters,
        X=X_init_prepped,
        n_blocks=n_blocks,
        n_components=n_components,
        inverse_cdf=inverse_cdf,
        init_mixcdf=init_mixcdf,
        mixture=mixture,
        n_reflections=n_reflections,
        init_rotation=init_rotation,
        return_transform=True,
    )
else:
    raise ValueError(f"Unrecognized Model: {model}")
# Out:
# Filter: (2, 2) - Layer: 0:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 0 | X: (5000, 784) (Splines):   0%|          | 0/10 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 1 | X: (980000, 4) (Householder):   0%|          | 0/10 [00:01<?, ?it/s]
# Initializing - Block: 1 | Layer 1 | X: (980000, 4) (Householder):  10%|█         | 1/10 [00:01<00:15,  1.72s/it]
# Initializing - Block: 2 | Layer 2 | X: (5000, 784) (Splines):  10%|█         | 1/10 [00:01<00:15,  1.72s/it]
# Initializing - Block: 2 | Layer 3 | X: (980000, 4) (Householder):  10%|█         | 1/10 [00:02<00:15,  1.72s/it]
# Initializing - Block: 2 | Layer 3 | X: (980000, 4) (Householder):  20%|██        | 2/10 [00:02<00:08,  1.04s/it]
# Initializing - Block: 3 | Layer 4 | X: (5000, 784) (Splines):  20%|██        | 2/10 [00:02<00:08,  1.04s/it]
# Initializing - Block: 3 | Layer 5 | X: (980000, 4) (Householder):  20%|██        | 2/10 [00:02<00:08,  1.04s/it]
# Initializing - Block: 3 | Layer 5 | X: (980000, 4) (Householder):  30%|███       | 3/10 [00:02<00:05,  1.18it/s]
# Initializing - Block: 4 | Layer 6 | X: (5000, 784) (Splines):  30%|███       | 3/10 [00:02<00:05,  1.18it/s]
# Initializing - Block: 4 | Layer 7 | X: (980000, 4) (Householder):  30%|███       | 3/10 [00:03<00:05,  1.18it/s]
# Initializing - Block: 4 | Layer 7 | X: (980000, 4) (Householder):  40%|████      | 4/10 [00:03<00:04,  1.32it/s]
# Initializing - Block: 5 | Layer 8 | X: (5000, 784) (Splines):  40%|████      | 4/10 [00:03<00:04,  1.32it/s]
# Initializing - Block: 5 | Layer 9 | X: (980000, 4) (Householder):  40%|████      | 4/10 [00:03<00:04,  1.32it/s]
# Initializing - Block: 5 | Layer 9 | X: (980000, 4) (Householder):  50%|█████     | 5/10 [00:04<00:03,  1.46it/s]
# Initializing - Block: 6 | Layer 10 | X: (5000, 784) (Splines):  50%|█████     | 5/10 [00:04<00:03,  1.46it/s]
# Initializing - Block: 6 | Layer 11 | X: (980000, 4) (Householder):  50%|█████     | 5/10 [00:04<00:03,  1.46it/s]
# Initializing - Block: 6 | Layer 11 | X: (980000, 4) (Householder):  60%|██████    | 6/10 [00:04<00:02,  1.57it/s]
# Initializing - Block: 7 | Layer 12 | X: (5000, 784) (Splines):  60%|██████    | 6/10 [00:04<00:02,  1.57it/s]
# Initializing - Block: 7 | Layer 13 | X: (980000, 4) (Householder):  60%|██████    | 6/10 [00:05<00:02,  1.57it/s]
# Initializing - Block: 7 | Layer 13 | X: (980000, 4) (Householder):  70%|███████   | 7/10 [00:05<00:01,  1.65it/s]
# Initializing - Block: 8 | Layer 14 | X: (5000, 784) (Splines):  70%|███████   | 7/10 [00:05<00:01,  1.65it/s]
# Initializing - Block: 8 | Layer 15 | X: (980000, 4) (Householder):  70%|███████   | 7/10 [00:05<00:01,  1.65it/s]
# Initializing - Block: 8 | Layer 15 | X: (980000, 4) (Householder):  80%|████████  | 8/10 [00:05<00:01,  1.71it/s]
# Initializing - Block: 9 | Layer 16 | X: (5000, 784) (Splines):  80%|████████  | 8/10 [00:05<00:01,  1.71it/s]
# Initializing - Block: 9 | Layer 17 | X: (980000, 4) (Householder):  80%|████████  | 8/10 [00:06<00:01,  1.71it/s]
# Initializing - Block: 9 | Layer 17 | X: (980000, 4) (Householder):  90%|█████████ | 9/10 [00:06<00:00,  1.81it/s]
# Initializing - Block: 10 | Layer 18 | X: (5000, 784) (Splines):  90%|█████████ | 9/10 [00:06<00:00,  1.81it/s]
# Initializing - Block: 10 | Layer 19 | X: (980000, 4) (Householder):  90%|█████████ | 9/10 [00:06<00:00,  1.81it/s]
# Initializing - Block: 10 | Layer 19 | X: (980000, 4) (Householder): 100%|██████████| 10/10 [00:06<00:00,  1.72it/s]
# Filter: (4, 4) - Layer: 1:  20%|██        | 1/5 [00:06<00:27,  6.85s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 0 | X: (5000, 784) (Splines):   0%|          | 0/10 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 1 | X: (245000, 16) (Householder):   0%|          | 0/10 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 1 | X: (245000, 16) (Householder):  10%|█         | 1/10 [00:00<00:07,  1.16it/s]
# Initializing - Block: 2 | Layer 2 | X: (5000, 784) (Splines):  10%|█         | 1/10 [00:00<00:07,  1.16it/s]
# Initializing - Block: 2 | Layer 3 | X: (245000, 16) (Householder):  10%|█         | 1/10 [00:01<00:07,  1.16it/s]
# Initializing - Block: 2 | Layer 3 | X: (245000, 16) (Householder):  20%|██        | 2/10 [00:01<00:05,  1.59it/s]
# Initializing - Block: 3 | Layer 4 | X: (5000, 784) (Splines):  20%|██        | 2/10 [00:01<00:05,  1.59it/s]
# Initializing - Block: 3 | Layer 5 | X: (245000, 16) (Householder):  20%|██        | 2/10 [00:01<00:05,  1.59it/s]
# Initializing - Block: 3 | Layer 5 | X: (245000, 16) (Householder):  30%|███       | 3/10 [00:01<00:04,  1.72it/s]
# Initializing - Block: 4 | Layer 6 | X: (5000, 784) (Splines):  30%|███       | 3/10 [00:01<00:04,  1.72it/s]
# Initializing - Block: 4 | Layer 7 | X: (245000, 16) (Householder):  30%|███       | 3/10 [00:02<00:04,  1.72it/s]
# Initializing - Block: 4 | Layer 7 | X: (245000, 16) (Householder):  40%|████      | 4/10 [00:02<00:03,  1.83it/s]
# Initializing - Block: 5 | Layer 8 | X: (5000, 784) (Splines):  40%|████      | 4/10 [00:02<00:03,  1.83it/s]
# Initializing - Block: 5 | Layer 9 | X: (245000, 16) (Householder):  40%|████      | 4/10 [00:02<00:03,  1.83it/s]
# Initializing - Block: 5 | Layer 9 | X: (245000, 16) (Householder):  50%|█████     | 5/10 [00:02<00:02,  1.91it/s]
# Initializing - Block: 6 | Layer 10 | X: (5000, 784) (Splines):  50%|█████     | 5/10 [00:02<00:02,  1.91it/s]
# Initializing - Block: 6 | Layer 11 | X: (245000, 16) (Householder):  50%|█████     | 5/10 [00:03<00:02,  1.91it/s]
# Initializing - Block: 6 | Layer 11 | X: (245000, 16) (Householder):  60%|██████    | 6/10 [00:03<00:02,  1.95it/s]
# Initializing - Block: 7 | Layer 12 | X: (5000, 784) (Splines):  60%|██████    | 6/10 [00:03<00:02,  1.95it/s]
# Initializing - Block: 7 | Layer 13 | X: (245000, 16) (Householder):  60%|██████    | 6/10 [00:03<00:02,  1.95it/s]
# Initializing - Block: 7 | Layer 13 | X: (245000, 16) (Householder):  70%|███████   | 7/10 [00:03<00:01,  1.94it/s]
# Initializing - Block: 8 | Layer 14 | X: (5000, 784) (Splines):  70%|███████   | 7/10 [00:03<00:01,  1.94it/s]
# Initializing - Block: 8 | Layer 15 | X: (245000, 16) (Householder):  70%|███████   | 7/10 [00:04<00:01,  1.94it/s]
# Initializing - Block: 8 | Layer 15 | X: (245000, 16) (Householder):  80%|████████  | 8/10 [00:04<00:01,  1.89it/s]
# Initializing - Block: 9 | Layer 16 | X: (5000, 784) (Splines):  80%|████████  | 8/10 [00:04<00:01,  1.89it/s]
# Initializing - Block: 9 | Layer 17 | X: (245000, 16) (Householder):  80%|████████  | 8/10 [00:04<00:01,  1.89it/s]
# Initializing - Block: 9 | Layer 17 | X: (245000, 16) (Householder):  90%|█████████ | 9/10 [00:04<00:00,  1.87it/s]
# Initializing - Block: 10 | Layer 18 | X: (5000, 784) (Splines):  90%|█████████ | 9/10 [00:04<00:00,  1.87it/s]
# Initializing - Block: 10 | Layer 19 | X: (245000, 16) (Householder):  90%|█████████ | 9/10 [00:05<00:00,  1.87it/s]
# Initializing - Block: 10 | Layer 19 | X: (245000, 16) (Householder): 100%|██████████| 10/10 [00:05<00:00,  1.86it/s]
# Filter: (7, 7) - Layer: 2:  40%|████      | 2/5 [00:12<00:18,  6.06s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 0 | X: (5000, 784) (Splines):   0%|          | 0/10 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 1 | X: (80000, 49) (Householder):   0%|          | 0/10 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 1 | X: (80000, 49) (Householder):  10%|█         | 1/10 [00:00<00:08,  1.03it/s]
# Initializing - Block: 2 | Layer 2 | X: (5000, 784) (Splines):  10%|█         | 1/10 [00:00<00:08,  1.03it/s]
# Initializing - Block: 2 | Layer 3 | X: (80000, 49) (Householder):  10%|█         | 1/10 [00:01<00:08,  1.03it/s]
# Initializing - Block: 2 | Layer 3 | X: (80000, 49) (Householder):  20%|██        | 2/10 [00:01<00:06,  1.33it/s]
# Initializing - Block: 3 | Layer 4 | X: (5000, 784) (Splines):  20%|██        | 2/10 [00:01<00:06,  1.33it/s]
# Initializing - Block: 3 | Layer 5 | X: (80000, 49) (Householder):  20%|██        | 2/10 [00:01<00:06,  1.33it/s]
# Initializing - Block: 3 | Layer 5 | X: (80000, 49) (Householder):  30%|███       | 3/10 [00:02<00:04,  1.45it/s]
# Initializing - Block: 4 | Layer 6 | X: (5000, 784) (Splines):  30%|███       | 3/10 [00:02<00:04,  1.45it/s]
# Initializing - Block: 4 | Layer 7 | X: (80000, 49) (Householder):  30%|███       | 3/10 [00:02<00:04,  1.45it/s]
# Initializing - Block: 4 | Layer 7 | X: (80000, 49) (Householder):  40%|████      | 4/10 [00:02<00:03,  1.63it/s]
# Initializing - Block: 5 | Layer 8 | X: (5000, 784) (Splines):  40%|████      | 4/10 [00:02<00:03,  1.63it/s]
# Initializing - Block: 5 | Layer 9 | X: (80000, 49) (Householder):  40%|████      | 4/10 [00:03<00:03,  1.63it/s]
# Initializing - Block: 5 | Layer 9 | X: (80000, 49) (Householder):  50%|█████     | 5/10 [00:03<00:02,  1.76it/s]
# Initializing - Block: 6 | Layer 10 | X: (5000, 784) (Splines):  50%|█████     | 5/10 [00:03<00:02,  1.76it/s]
# Initializing - Block: 6 | Layer 11 | X: (80000, 49) (Householder):  50%|█████     | 5/10 [00:03<00:02,  1.76it/s]
# Initializing - Block: 6 | Layer 11 | X: (80000, 49) (Householder):  60%|██████    | 6/10 [00:03<00:02,  1.84it/s]
# Initializing - Block: 7 | Layer 12 | X: (5000, 784) (Splines):  60%|██████    | 6/10 [00:03<00:02,  1.84it/s]
# Initializing - Block: 7 | Layer 13 | X: (80000, 49) (Householder):  60%|██████    | 6/10 [00:03<00:02,  1.84it/s]
# Initializing - Block: 7 | Layer 13 | X: (80000, 49) (Householder):  70%|███████   | 7/10 [00:04<00:01,  1.95it/s]
# Initializing - Block: 8 | Layer 14 | X: (5000, 784) (Splines):  70%|███████   | 7/10 [00:04<00:01,  1.95it/s]
# Initializing - Block: 8 | Layer 15 | X: (80000, 49) (Householder):  70%|███████   | 7/10 [00:04<00:01,  1.95it/s]
# Initializing - Block: 8 | Layer 15 | X: (80000, 49) (Householder):  80%|████████  | 8/10 [00:04<00:01,  1.96it/s]
# Initializing - Block: 9 | Layer 16 | X: (5000, 784) (Splines):  80%|████████  | 8/10 [00:04<00:01,  1.96it/s]
# Initializing - Block: 9 | Layer 17 | X: (80000, 49) (Householder):  80%|████████  | 8/10 [00:04<00:01,  1.96it/s]
# Initializing - Block: 9 | Layer 17 | X: (80000, 49) (Householder):  90%|█████████ | 9/10 [00:05<00:00,  1.97it/s]
# Initializing - Block: 10 | Layer 18 | X: (5000, 784) (Splines):  90%|█████████ | 9/10 [00:05<00:00,  1.97it/s]
# Initializing - Block: 10 | Layer 19 | X: (80000, 49) (Householder):  90%|█████████ | 9/10 [00:05<00:00,  1.97it/s]
# Initializing - Block: 10 | Layer 19 | X: (80000, 49) (Householder): 100%|██████████| 10/10 [00:05<00:00,  1.95it/s]
# Filter: (14, 14) - Layer: 3:  60%|██████    | 3/5 [00:18<00:11,  5.88s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 0 | X: (5000, 784) (Splines):   0%|          | 0/10 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 1 | X: (20000, 196) (Householder):   0%|          | 0/10 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 1 | X: (20000, 196) (Householder):  10%|█         | 1/10 [00:00<00:07,  1.13it/s]
# Initializing - Block: 2 | Layer 2 | X: (5000, 784) (Splines):  10%|█         | 1/10 [00:00<00:07,  1.13it/s]
# Initializing - Block: 2 | Layer 3 | X: (20000, 196) (Householder):  10%|█         | 1/10 [00:01<00:07,  1.13it/s]
# Initializing - Block: 2 | Layer 3 | X: (20000, 196) (Householder):  20%|██        | 2/10 [00:01<00:05,  1.42it/s]
# Initializing - Block: 3 | Layer 4 | X: (5000, 784) (Splines):  20%|██        | 2/10 [00:01<00:05,  1.42it/s]
# Initializing - Block: 3 | Layer 5 | X: (20000, 196) (Householder):  20%|██        | 2/10 [00:01<00:05,  1.42it/s]
# Initializing - Block: 3 | Layer 5 | X: (20000, 196) (Householder):  30%|███       | 3/10 [00:02<00:04,  1.52it/s]
# Initializing - Block: 4 | Layer 6 | X: (5000, 784) (Splines):  30%|███       | 3/10 [00:02<00:04,  1.52it/s]
# Initializing - Block: 4 | Layer 7 | X: (20000, 196) (Householder):  30%|███       | 3/10 [00:02<00:04,  1.52it/s]
# Initializing - Block: 4 | Layer 7 | X: (20000, 196) (Householder):  40%|████      | 4/10 [00:02<00:03,  1.54it/s]
# Initializing - Block: 5 | Layer 8 | X: (5000, 784) (Splines):  40%|████      | 4/10 [00:02<00:03,  1.54it/s]
# Initializing - Block: 5 | Layer 9 | X: (20000, 196) (Householder):  40%|████      | 4/10 [00:03<00:03,  1.54it/s]
# Initializing - Block: 5 | Layer 9 | X: (20000, 196) (Householder):  50%|█████     | 5/10 [00:03<00:03,  1.45it/s]
# Initializing - Block: 6 | Layer 10 | X: (5000, 784) (Splines):  50%|█████     | 5/10 [00:03<00:03,  1.45it/s]
# Initializing - Block: 6 | Layer 11 | X: (20000, 196) (Householder):  50%|█████     | 5/10 [00:03<00:03,  1.45it/s]
# Initializing - Block: 6 | Layer 11 | X: (20000, 196) (Householder):  60%|██████    | 6/10 [00:04<00:02,  1.50it/s]
# Initializing - Block: 7 | Layer 12 | X: (5000, 784) (Splines):  60%|██████    | 6/10 [00:04<00:02,  1.50it/s]
# Initializing - Block: 7 | Layer 13 | X: (20000, 196) (Householder):  60%|██████    | 6/10 [00:04<00:02,  1.50it/s]
# Initializing - Block: 7 | Layer 13 | X: (20000, 196) (Householder):  70%|███████   | 7/10 [00:04<00:01,  1.55it/s]
# Initializing - Block: 8 | Layer 14 | X: (5000, 784) (Splines):  70%|███████   | 7/10 [00:04<00:01,  1.55it/s]
# Initializing - Block: 8 | Layer 15 | X: (20000, 196) (Householder):  70%|███████   | 7/10 [00:05<00:01,  1.55it/s]
# Initializing - Block: 8 | Layer 15 | X: (20000, 196) (Householder):  80%|████████  | 8/10 [00:05<00:01,  1.42it/s]
# Initializing - Block: 9 | Layer 16 | X: (5000, 784) (Splines):  80%|████████  | 8/10 [00:05<00:01,  1.42it/s]
# Initializing - Block: 9 | Layer 17 | X: (20000, 196) (Householder):  80%|████████  | 8/10 [00:05<00:01,  1.42it/s]
# Initializing - Block: 9 | Layer 17 | X: (20000, 196) (Householder):  90%|█████████ | 9/10 [00:06<00:00,  1.47it/s]
# Initializing - Block: 10 | Layer 18 | X: (5000, 784) (Splines):  90%|█████████ | 9/10 [00:06<00:00,  1.47it/s]
# Initializing - Block: 10 | Layer 19 | X: (20000, 196) (Householder):  90%|█████████ | 9/10 [00:06<00:00,  1.47it/s]
# Initializing - Block: 10 | Layer 19 | X: (20000, 196) (Householder): 100%|██████████| 10/10 [00:06<00:00,  1.52it/s]
# Filter: (28, 28) - Layer: 4:  80%|████████  | 4/5 [00:24<00:06,  6.22s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 0 | X: (5000, 784) (Splines):   0%|          | 0/10 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 1 | X: (5000, 784) (Householder):   0%|          | 0/10 [00:00<?, ?it/s]
# Initializing - Block: 1 | Layer 1 | X: (5000, 784) (Householder):  10%|█         | 1/10 [00:00<00:07,  1.28it/s]
# Initializing - Block: 2 | Layer 2 | X: (5000, 784) (Splines):  10%|█         | 1/10 [00:00<00:07,  1.28it/s]
# Initializing - Block: 2 | Layer 3 | X: (5000, 784) (Householder):  10%|█         | 1/10 [00:01<00:07,  1.28it/s]
# Initializing - Block: 2 | Layer 3 | X: (5000, 784) (Householder):  20%|██        | 2/10 [00:01<00:05,  1.47it/s]
# Initializing - Block: 3 | Layer 4 | X: (5000, 784) (Splines):  20%|██        | 2/10 [00:01<00:05,  1.47it/s]
# Initializing - Block: 3 | Layer 5 | X: (5000, 784) (Householder):  20%|██        | 2/10 [00:01<00:05,  1.47it/s]
# Initializing - Block: 3 | Layer 5 | X: (5000, 784) (Householder):  30%|███       | 3/10 [00:01<00:04,  1.57it/s]
# Initializing - Block: 4 | Layer 6 | X: (5000, 784) (Splines):  30%|███       | 3/10 [00:01<00:04,  1.57it/s]
# Initializing - Block: 4 | Layer 7 | X: (5000, 784) (Householder):  30%|███       | 3/10 [00:02<00:04,  1.57it/s]
# Initializing - Block: 4 | Layer 7 | X: (5000, 784) (Householder):  40%|████      | 4/10 [00:02<00:03,  1.56it/s]
# Initializing - Block: 5 | Layer 8 | X: (5000, 784) (Splines):  40%|████      | 4/10 [00:02<00:03,  1.56it/s]
# Initializing - Block: 5 | Layer 9 | X: (5000, 784) (Householder):  40%|████      | 4/10 [00:02<00:03,  1.56it/s]
# Initializing - Block: 5 | Layer 9 | X: (5000, 784) (Householder):  50%|█████     | 5/10 [00:03<00:03,  1.60it/s]
# Initializing - Block: 6 | Layer 10 | X: (5000, 784) (Splines):  50%|█████     | 5/10 [00:03<00:03,  1.60it/s]
# Initializing - Block: 6 | Layer 11 | X: (5000, 784) (Householder):  50%|█████     | 5/10 [00:03<00:03,  1.60it/s]
# Initializing - Block: 6 | Layer 11 | X: (5000, 784) (Householder):  60%|██████    | 6/10 [00:03<00:02,  1.60it/s]
# Initializing - Block: 7 | Layer 12 | X: (5000, 784) (Splines):  60%|██████    | 6/10 [00:03<00:02,  1.60it/s]
# Initializing - Block: 7 | Layer 13 | X: (5000, 784) (Householder):  60%|██████    | 6/10 [00:04<00:02,  1.60it/s]
# Initializing - Block: 7 | Layer 13 | X: (5000, 784) (Householder):  70%|███████   | 7/10 [00:04<00:01,  1.64it/s]
# Initializing - Block: 8 | Layer 14 | X: (5000, 784) (Splines):  70%|███████   | 7/10 [00:04<00:01,  1.64it/s]
# Initializing - Block: 8 | Layer 15 | X: (5000, 784) (Householder):  70%|███████   | 7/10 [00:04<00:01,  1.64it/s]
# Initializing - Block: 8 | Layer 15 | X: (5000, 784) (Householder):  80%|████████  | 8/10 [00:05<00:01,  1.66it/s]
# Initializing - Block: 9 | Layer 16 | X: (5000, 784) (Splines):  80%|████████  | 8/10 [00:05<00:01,  1.66it/s]
# Initializing - Block: 9 | Layer 17 | X: (5000, 784) (Householder):  80%|████████  | 8/10 [00:05<00:01,  1.66it/s]
# Initializing - Block: 9 | Layer 17 | X: (5000, 784) (Householder):  90%|█████████ | 9/10 [00:05<00:00,  1.63it/s]
# Initializing - Block: 10 | Layer 18 | X: (5000, 784) (Splines):  90%|█████████ | 9/10 [00:05<00:00,  1.63it/s]
# Initializing - Block: 10 | Layer 19 | X: (5000, 784) (Householder):  90%|█████████ | 9/10 [00:05<00:00,  1.63it/s]
# Initializing - Block: 10 | Layer 19 | X: (5000, 784) (Householder): 100%|██████████| 10/10 [00:06<00:00,  1.64it/s]
# Filter: (28, 28) - Layer: 4: 100%|██████████| 5/5 [00:31<00:00,  6.21s/it]

# %% [markdown]
# ### Demo Transformation

# %% [markdown]
# #### Forward

# %%
# plot demo images
# plot image grid
fig, ax = plot_image_grid(X_g, image_shape)

# %%
fig = corner.corner(np.array(X_g[:, :10]), color="red")

# %% [markdown]
# ### Initial Score

# %% [markdown]
# #### Negative Log-Likelihood

# %%
# %%time


init_nll_score = gf_model.score(X_init_prepped[:64])

print(f"NLL", init_nll_score)
# Out:
# NLL -105.82677
# CPU times: user 4.48 s, sys: 83.7 ms, total: 4.56 s
# Wall time: 4.22 s

# %% [markdown]
# #### NLL - Bits per Dimension

# %%
from rbig_jax.losses import nll_2_bpd

# jit the loss
nll_2_bpd = jax.jit(nll_2_bpd)

init_nll_score_bpd = nll_2_bpd(init_nll_score, image_shape)

print(f"NLL (bits-per-dim)", init_nll_score_bpd)
# Out:
# NLL (bits-per-dim) -0.19473949

# %% [markdown]
# #### Inverse

# %%
# %%time

# forward propagation for data
X_demo_approx = gf_model.inverse(X_g[:25])
# Out:
# CPU times: user 7.04 s, sys: 49.9 ms, total: 7.09 s
# Wall time: 6.94 s

# %%
jnp.mean(jnp.abs(X_demo_approx - X_init_prepped[:25]))
# Out:
# DeviceArray(2.1363856e-07, dtype=float32)

# %%
# plot demo images
plot_image_grid(X_demo_approx, image_shape)
# Out:
# (<Figure size 720x720 with 50 Axes>,
#  <mpl_toolkits.axes_grid1.axes_grid.ImageGrid at 0x7f76ac6dc4c0>)

# %% [markdown]
# ### Loss Function
#
# We're going to minimize the log probability

# %%
from rbig_jax.training.parametric import init_optimizer

n_epochs = 5_000
# initialize optimizer
optimizer = init_optimizer(
    "adam", lr=1e-4, cosine_decay_steps=None, gradient_norm_clip=1.0, alpha=1e-1,
)

# %% [markdown]
# ### NF Trainer

# %%
from rbig_jax.training.parametric import GaussFlowTrainer

# initial flow trainer
nf_trainer = GaussFlowTrainer(
    gf_model, optimizer, n_epochs=n_epochs, prepare_data_fn=prepare_data
)

# %% [markdown]
# ### DataLoaders

# %%
import tensorflow_datasets as tfds
from typing import Iterator, Mapping
from sklearn import datasets
import numpy as np
import tensorflow as tf

Batch = Mapping[str, np.ndarray]

# %%
def load_dataset(split: str = "train", batch_size: int = 123) -> Iterator[Batch]:
    (X_train, _), (X_test, _) = tf.keras.datasets.mnist.load_data()
    if split == "train":
        ds = tf.data.Dataset.from_tensor_slices((X_train))
    elif split == "test":
        ds = tf.data.Dataset.from_tensor_slices((X_test))
    else:
        raise ValueError(f"Unrecognized split")

    if split == "train":
        ds = ds.shuffle(buffer_size=10 * batch_size)
    ds = ds.batch(batch_size)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    ds = ds.repeat()
    return iter(tfds.as_numpy(ds))

# %%
train_batch_size = 128
valid_batch_size = 128

train_ds = load_dataset("train", train_batch_size)
valid_ds = load_dataset("test", valid_batch_size)

# %%
# number of epochs
# epochs = 250
eval_frequency = 50

# split the keys into a unique subset
train_rng = jax.random.split(rng, num=n_epochs)

# create an iterator
train_rng = iter(train_rng)

# %% [markdown]
# ### Train Loop

# %%
# %%wandb

import tqdm

eval_loss = 0.0
eval_frequency = 50
with tqdm.trange(n_epochs) as pbar:
    for step in pbar:

        # Train Step
        output = nf_trainer.train_step(next(train_ds), rng=next(train_rng))
        train_loss = output.loss
        train_loss = nll_2_bpd(train_loss, image_shape)
        pbar.set_description(
            f"Train Loss: {train_loss:.4f} | Valid Loss: {eval_loss:.4f}"
        )

        # Eval Step
        if step % eval_frequency == 0:
            output = nf_trainer.validation_step(next(valid_ds))
            eval_loss = output.loss
            eval_loss = nll_2_bpd(eval_loss, image_shape)
            pbar.set_description(
                f"Train Loss: {train_loss:.4f} | Valid Loss: {eval_loss:.4f}"
            )

gf_model = output.model
# Out:
# Train Loss: -4.9713 | Valid Loss: -4.6099:  99%|█████████▊| 4927/5000 [32:05<00:27,  2.65it/s]  IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Results

# %%
fig, ax = plt.subplots()
ax.plot(
    nf_trainer.train_epoch, nf_trainer.train_loss, label="Training Loss", color="blue"
)
ax.plot(
    nf_trainer.valid_epoch,
    nf_trainer.valid_loss,
    label="Validation Loss",
    color="orange",
)
ax.set(
    xlabel="Iterations", ylabel="Negative Log-Likelihood",
)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# %%time

# forward propagation for data
X_demo_g = gf_model.forward(X_init_prepped[:64])

# plot demo images
# plot image grid
fig, ax = plot_image_grid(X_demo_g, image_shape)
# Out:
# CPU times: user 3.72 s, sys: 64.3 ms, total: 3.79 s
# Wall time: 3.53 s

# %%
fig = corner.corner(np.array(X_demo_g[:, :10]), color="red")
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %%
# %%time

# forward propagation for data
X_demo_approx = gf_model.inverse(X_demo_g)

# plot demo images
# plot image grid
fig, ax = plot_image_grid(X_demo_approx, image_shape)
# plot image grid
# Out:
# CPU times: user 3.93 s, sys: 105 ms, total: 4.03 s
# Wall time: 3.73 s

# %% [markdown]
# ### Sampling

# %%
# %%time

# X_g_samples = jax.random.randn((5_000, 784))
n_gen_samples = 50
X_samples = gf_model.sample(seed=123, n_samples=n_gen_samples)

# plot
fig, ax = plot_image_grid(X_samples, image_shape)
# Out:
# CPU times: user 5.54 s, sys: 94 ms, total: 5.64 s
# Wall time: 5.34 s

# %%
fig = corner.corner(np.array(X_samples[:, :5]), color="Blue")
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %%
X_g = X_init.copy()[:50]

fig = corner.corner(X_g, color="purple")
fig.suptitle("Initial")
plt.show()

for ilayer, ibijector in enumerate(gf_model.bijectors):
    
    X_g = ibijector.forward(X_g)
    
    if (ilayer+1) % 3 == 0:
        fig = corner.corner(X_g[:,:5], color="purple")
        fig.suptitle(f"Block: {(ilayer+1)//3}")
        plt.show()
        
        break
# Out:
# Error in callback <function _WandbInit._resume_backend at 0x7f0d6061f790> (for pre_run_cell):
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/backcall/backcall.py in adapted(*args, **kwargs)
#     102                 kwargs.pop(name)
#     103 #            print(args, kwargs, unmatched_pos, cut_positional, unmatched_kw)
# --> 104             return callback(*args, **kwargs)
#     105
#     106         return adapted
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/wandb_init.py in _resume_backend(self)
#     257         if self.backend is not None:
#     258             logger.info("resuming backend")
# --> 259             self.backend.interface.publish_resume()
#     260
#     261     def _jupyter_teardown(self):
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/interface/interface.py in publish_resume(self)
#     595         resume = pb.ResumeRequest()
#     596         rec = self._make_request(resume=resume)
# --> 597         self._publish(rec)
#     598
#     599     def _publish_run(self, run: pb.RunRecord) -> None:
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/interface/interface.py in _publish(self, record, local)
#     526     def _publish(self, record: pb.Record, local: bool = None) -> None:
#     527         if self._process and not self._process.is_alive():
# --> 528             raise Exception("The wandb backend process has shutdown")
#     529         if local:
#     530             record.control.local = local
#
# Exception: The wandb backend process has shutdown
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-57-833f71363764> in <module>
#       1 X_g = X_init.copy()[:50]
#       2
# ----> 3 fig = corner.corner(X_g, color="purple")
#       4 fig.suptitle("Initial")
#       5 plt.show()
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/corner/corner.py in corner(xs, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, **hist2d_kwargs)
#     191         assert len(xs.shape) == 2, "The input sample array must be 1- or 2-D."
#     192         xs = xs.T
# --> 193     assert xs.shape[0] <= xs.shape[1], (
#     194         "I don't believe that you want more " "dimensions than samples!"
#     195     )
#
# AssertionError: I don't believe that you want more dimensions than samples!
# Error in callback <function _WandbInit._pause_backend at 0x7f0d6061f310> (for post_run_cell):
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/backcall/backcall.py in adapted(*args, **kwargs)
#     102                 kwargs.pop(name)
#     103 #            print(args, kwargs, unmatched_pos, cut_positional, unmatched_kw)
# --> 104             return callback(*args, **kwargs)
#     105
#     106         return adapted
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/wandb_init.py in _pause_backend(self)
#     252                 res = self.run.log_code(root=None)
#     253                 logger.info("saved code: %s", res)
# --> 254             self.backend.interface.publish_pause()
#     255
#     256     def _resume_backend(self):
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/interface/interface.py in publish_pause(self)
#     590         pause = pb.PauseRequest()
#     591         rec = self._make_request(pause=pause)
# --> 592         self._publish(rec)
#     593
#     594     def publish_resume(self) -> None:
#
# ~/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/interface/interface.py in _publish(self, record, local)
#     526     def _publish(self, record: pb.Record, local: bool = None) -> None:
#     527         if self._process and not self._process.is_alive():
# --> 528             raise Exception("The wandb backend process has shutdown")
#     529         if local:
#     530             record.control.local = local
#
# Exception: The wandb backend process has shutdown
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "/home/emmanuel/.conda/envs/jax_py38/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/emmanuel/.conda/envs/jax_py38/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/emmanuel/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/wandb_run.py", line 198, in check_status
#     status_response = self._interface.communicate_stop_status()
#   File "/home/emmanuel/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/interface/interface.py", line 735, in communicate_stop_status
#     resp = self._communicate(req, timeout=timeout, local=True)
#   File "/home/emmanuel/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/interface/interface.py", line 537, in _communicate
#     return self._communicate_async(rec, local=local).get(timeout=timeout)
#   File "/home/emmanuel/.conda/envs/jax_py38/lib/python3.8/site-packages/wandb/sdk/interface/interface.py", line 542, in _communicate_async
#     raise Exception("The wandb backend process has shutdown")
# Exception: The wandb backend process has shutdown

# %%
fig, ax = plt.subplots()
ax.scatter(X_g[:, 0], X_g[:, 1], s=3)
ax.set_aspect('equal', 'box')
plt.tight_layout()

# %% [markdown]
# ## Saving/Loading Model

# %%
import joblib

# %% [markdown]
# #### Save Model

# %%
model_save_name = os.path.join(wandb.run.dir, "gf_model.pckl")
joblib.dump(gf_model, model_save_name)
wandb.save(model_save_name)
# Out:
# ['gf_model_mnist.pickle']

# %% [markdown]
# #### Load Model

# %%
gf_model_ = joblib.load(model_save_name)
